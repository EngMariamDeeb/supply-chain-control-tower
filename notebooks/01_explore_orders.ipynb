# %%
import pandas as pd
orders = pd.read_csv('../data/orders.csv')
orders
# Out:
#     order_id product_id customer_id  quantity_ordered  order_date  \
# 0   ORD-0001   PROD-010    CUST-005                20  2026-01-05
# 1   ORD-0002   PROD-003    CUST-002                 5  2026-01-06
# 2   ORD-0003   PROD-007    CUST-001                15  2026-01-07
# 3   ORD-0004   PROD-002    CUST-004                10  2026-01-08
# 4   ORD-0005   PROD-005    CUST-009                 8  2026-01-09
# 5   ORD-0006   PROD-001    CUST-006                12  2026-01-10
# 6   ORD-0007   PROD-004    CUST-007                25  2026-01-11
# 7   ORD-0008   PROD-008    CUST-008                30  2026-01-12
# 8   ORD-0009   PROD-009    CUST-009                18  2026-01-13
# 9   ORD-0010   PROD-007    CUST-010                22  2026-01-14
# 10  ORD-0011   PROD-010    CUST-011                14  2026-01-15
# 11  ORD-0012   PROD-012    CUST-012                 7  2026-01-16
#
#    expected_delivery_date actual_delivery_date order_status
# 0              2026-01-12           2026-01-11    Delivered
# 1              2026-01-13                  NaN      Pending
# 2              2026-01-14           2026-01-13    Delivered
# 3              2026-01-15           2026-01-17    Delivered
# 4              2026-01-16                  NaN    Cancelled
# 5              2026-01-17                  NaN     Delayed
# 6              2026-01-18           2026-01-21    Delivered
# 7              2026-01-19                  NaN      Pending
# 8              2026-01-20           2026-01-20    Delivered
# 9              2026-01-21                  NaN      Delayed
# 10             2026-01-22           2026-01-23    Delivered
# 11             2026-01-23                  NaN      Pending

# %%
orders.head()
# Out:
#    order_id product_id customer_id  quantity_ordered  order_date  \
# 0  ORD-0001   PROD-010    CUST-005                20  2026-01-05
# 1  ORD-0002   PROD-003    CUST-002                 5  2026-01-06
# 2  ORD-0003   PROD-007    CUST-001                15  2026-01-07
# 3  ORD-0004   PROD-002    CUST-004                10  2026-01-08
# 4  ORD-0005   PROD-005    CUST-009                 8  2026-01-09
#
#   expected_delivery_date actual_delivery_date order_status
# 0             2026-01-12           2026-01-11    Delivered
# 1             2026-01-13                  NaN      Pending
# 2             2026-01-14           2026-01-13    Delivered
# 3             2026-01-15           2026-01-17    Delivered
# 4             2026-01-16                  NaN    Cancelled

# %%
orders.describe()
# Out:
#        quantity_ordered
# count          12.00000
# mean           15.50000
# std             7.70478
# min             5.00000
# 25%             9.50000
# 50%            14.50000
# 75%            20.50000
# max            30.00000

# %%
orders.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   order_id                12 non-null     str
#  1   product_id              12 non-null     str
#  2   customer_id             12 non-null     str
#  3   quantity_ordered        12 non-null     int64
#  4   order_date              12 non-null     str
#  5   expected_delivery_date  12 non-null     str
#  6   actual_delivery_date    6 non-null      str
#  7   order_status            12 non-null     str
# dtypes: int64(1), str(7)
# memory usage: 900.0 bytes

# %%
orders['order_date'] = pd.to_datetime(orders['order_date'])
orders['expected_delivery_date'] = pd.to_datetime(orders['expected_delivery_date'])
orders['actual_delivery_date'] = pd.to_datetime(orders['actual_delivery_date'])

# %%
orders.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   order_id                12 non-null     str
#  1   product_id              12 non-null     str
#  2   customer_id             12 non-null     str
#  3   quantity_ordered        12 non-null     int64
#  4   order_date              12 non-null     datetime64[us]
#  5   expected_delivery_date  12 non-null     datetime64[us]
#  6   actual_delivery_date    6 non-null      datetime64[us]
#  7   order_status            12 non-null     str
# dtypes: datetime64[us](3), int64(1), str(4)
# memory usage: 900.0 bytes

# %%
orders['delivery_delay_days'] = (orders['actual_delivery_date'] - orders['expected_delivery_date']).dt.days
orders
# Out:
#     order_id product_id customer_id  quantity_ordered order_date  \
# 0   ORD-0001   PROD-010    CUST-005                20 2026-01-05
# 1   ORD-0002   PROD-003    CUST-002                 5 2026-01-06
# 2   ORD-0003   PROD-007    CUST-001                15 2026-01-07
# 3   ORD-0004   PROD-002    CUST-004                10 2026-01-08
# 4   ORD-0005   PROD-005    CUST-009                 8 2026-01-09
# 5   ORD-0006   PROD-001    CUST-006                12 2026-01-10
# 6   ORD-0007   PROD-004    CUST-007                25 2026-01-11
# 7   ORD-0008   PROD-008    CUST-008                30 2026-01-12
# 8   ORD-0009   PROD-009    CUST-009                18 2026-01-13
# 9   ORD-0010   PROD-007    CUST-010                22 2026-01-14
# 10  ORD-0011   PROD-010    CUST-011                14 2026-01-15
# 11  ORD-0012   PROD-012    CUST-012                 7 2026-01-16
#
#    expected_delivery_date actual_delivery_date order_status  \
# 0              2026-01-12           2026-01-11    Delivered
# 1              2026-01-13                  NaT      Pending
# 2              2026-01-14           2026-01-13    Delivered
# 3              2026-01-15           2026-01-17    Delivered
# 4              2026-01-16                  NaT    Cancelled
# 5              2026-01-17                  NaT     Delayed
# 6              2026-01-18           2026-01-21    Delivered
# 7              2026-01-19                  NaT      Pending
# 8              2026-01-20           2026-01-20    Delivered
# 9              2026-01-21                  NaT      Delayed
# 10             2026-01-22           2026-01-23    Delivered
# 11             2026-01-23                  NaT      Pending
#
#     delivery_delay_days
# 0                  -1.0
# 1                   NaN
# 2                  -1.0
# 3                   2.0
# 4                   NaN
# 5                   NaN
# 6                   3.0
# 7                   NaN
# 8                   0.0
# 9                   NaN
# 10                  1.0
# 11                  NaN

# %%
mask = orders['order_status'] == 'Delivered' 
delivered_orders = orders[mask]
# delivered_orders = orders[orders['orders_status'] == 'delivered']
delivered_orders
# Out:
#     order_id product_id customer_id  quantity_ordered order_date  \
# 0   ORD-0001   PROD-010    CUST-005                20 2026-01-05
# 2   ORD-0003   PROD-007    CUST-001                15 2026-01-07
# 3   ORD-0004   PROD-002    CUST-004                10 2026-01-08
# 6   ORD-0007   PROD-004    CUST-007                25 2026-01-11
# 8   ORD-0009   PROD-009    CUST-009                18 2026-01-13
# 10  ORD-0011   PROD-010    CUST-011                14 2026-01-15
#
#    expected_delivery_date actual_delivery_date order_status  \
# 0              2026-01-12           2026-01-11    Delivered
# 2              2026-01-14           2026-01-13    Delivered
# 3              2026-01-15           2026-01-17    Delivered
# 6              2026-01-18           2026-01-21    Delivered
# 8              2026-01-20           2026-01-20    Delivered
# 10             2026-01-22           2026-01-23    Delivered
#
#     delivery_delay_days
# 0                  -1.0
# 2                  -1.0
# 3                   2.0
# 6                   3.0
# 8                   0.0
# 10                  1.0

# %%
on_time_mask = delivered_orders['delivery_delay_days'] <= 0
total_delivered = len(delivered_orders)
on_time_rate = (on_time_mask.sum() / total_delivered) * 100
on_time_rate
print(f"On-Time Delivery Rate: {on_time_rate:.1f}%")
# Out:
# On-Time Delivery Rate: 50.0%
